# %%
import pandas as pd
import requests 
import simplejson as json
import quandl

# %%
r = requests.get('https://www.quandl.com/api/v3/datatables/WIKI/PRICES.json?api_key=XyT1FY3chW_8gD_g4ytW')

# %%
r.headers
# Out:
# {'Date': 'Sat, 30 Dec 2017 03:37:44 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d957ccf9db9398b8770e0bf7f920fc1071514605063; expires=Sun, 30-Dec-18 03:37:43 GMT; path=/; domain=.quandl.com; HttpOnly', 'Cache-Control': 'max-age=0, private, must-revalidate', 'Cursor_ID': 'djFfMTAwMDFfMTUxNDYwNTA2NA==', 'ETag': 'W/"3818d1fa9a59e7abfe9934056c3b4f21"', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'SAMEORIGIN', 'X-RateLimit-Limit': '50000', 'X-RateLimit-Remaining': '49991', 'X-Request-Id': 'bf4c9ecd-6bd1-48f5-8ab2-3e20fb7b37c0', 'X-Runtime': '0.643433', 'X-XSS-Protection': '1; mode=block', 'Server': 'cloudflare-nginx', 'CF-RAY': '3d51f64f1faf23f0-IAD', 'Content-Encoding': 'gzip'}

# %%
df=pd.read_json('https://www.quandl.com/api/v3/datatables/WIKI/PRICES.json?api_key=XyT1FY3chW_8gD_g4ytW')

# %%
df['datatable']
# Out:
# columns           [{'name': 'ticker', 'type': 'String'}, {'name'...
# data              [[A, 1999-11-18, 45.5, 50.0, 40.0, 44.0, 44739...
# next_cursor_id                                                  NaN
# Name: datatable, dtype: object

# %%
dictionary = {'api_key':'XyT1FY3chW_8gD_g4ytW', 'date.lt':'2017-11-30', 'date.gt':'2017-11-01'}
r = requests.get('https://www.quandl.com/api/v3/datatables/WIKI/PRICES.json', params=dictionary)
x = r.json()
x.keys()
# Out:
# dict_keys(['datatable', 'meta'])

# %%
r=quandl.get("https://www.quandl.com/api/v3/datatables/WIKI/PRICES.json?api_key=XyT1FY3chW_8gD_g4ytW", start_date="2017-12-01")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-05cc95030c01> in <module>()
# ----> 1 r=quandl.get("https://www.quandl.com/api/v3/datatables/WIKI/PRICES.json?api_key=XyT1FY3chW_8gD_g4ytW", start_date="2017-12-01")
#
# ~/anaconda3/lib/python3.6/site-packages/quandl/get.py in get(dataset, **kwargs)
#      43     # Unicode String
#      44     if isinstance(dataset, string_types):
# ---> 45         dataset_args = _parse_dataset_code(dataset)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
#
# ~/anaconda3/lib/python3.6/site-packages/quandl/get.py in _parse_dataset_code(dataset)
#      69     dataset_temp = dataset.split('.')
#      70     if not dataset_temp[1].isdigit():
# ---> 71         raise ValueError(Message.ERROR_COLUMN_INDEX_TYPE % dataset)
# ...

# %%
data = quandl.get("WIKI/PRICES", start_date="2017-11-01", end_date="2017-11-30")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-5-db81a16f0f70> in <module>()
# ----> 1 data = quandl.get("WIKI/PRICES", start_date="2017-11-01", end_date="2017-11-30")
#
# ~/anaconda3/lib/python3.6/site-packages/quandl/get.py in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# ~/anaconda3/lib/python3.6/site-packages/quandl/model/dataset.py in data(self, **options)
#      45         updated_options = Util.merge_options('params', params, **options)
#      46         try:
# ---> 47             return Data.all(**updated_options)
#      48         except NotFoundError:
# ...

# %%
x.keys()
# Out:
# dict_keys(['quandl_error'])

# %%
df=pd.DataFrame(x['datatable']['columns'])
# Out:
#            name               type
# 0        ticker             String
# 1          date               Date
# 2          open  BigDecimal(34,12)
# 3          high  BigDecimal(34,12)
# 4           low  BigDecimal(34,12)
# 5         close  BigDecimal(34,12)
# 6        volume  BigDecimal(37,15)
# 7   ex-dividend  BigDecimal(42,20)
# 8   split_ratio             double
# 9      adj_open  BigDecimal(50,28)
# 10     adj_high  BigDecimal(50,28)
# 11      adj_low  BigDecimal(50,28)
# 12    adj_close  BigDecimal(50,28)
# 13   adj_volume             double

# %%
pd.DataFrame(x['datatable']['data'])
# Out:
#         0           1       2         3        4       5          6    7   \
# 0        A  2017-11-02   68.08   68.3800   67.810   68.13  1854678.0  0.0
# 1        A  2017-11-03   68.09   68.6700   68.010   68.37  1070662.0  0.0
# 2        A  2017-11-06   68.27   68.4500   67.870   68.22   991668.0  0.0
# 3        A  2017-11-07   68.32   68.6400   68.040   68.25   946235.0  0.0
# 4        A  2017-11-09   67.92   67.9800   66.910   67.47  1664971.0  0.0
# 5        A  2017-11-10   67.35   67.5800   66.700   66.81  1704341.0  0.0
# 6        A  2017-11-13   66.45   67.3900   66.250   67.13  1443239.0  0.0
# 7        A  2017-11-14   66.98   67.8000   66.890   67.46  1682158.0  0.0
# 8        A  2017-11-15   67.29   67.5600   66.910   67.31  1511323.0  0.0
# 9        A  2017-11-16   67.50   68.9500   67.450   68.74  2268333.0  0.0
# 10       A  2017-11-17   68.53   69.0900   68.290   68.79  1816997.0  0.0
# 11       A  2017-11-20   69.28   70.2300   68.950   69.96  4014526.0  0.0
# ...

# %%
x['datatable'].keys()
# Out:
# dict_keys(['data', 'columns'])

# %%
df = pd.DataFrame(x['datatable'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-f79ec55487be> in <module>()
# ----> 1 df = pd.DataFrame(x['data'])
#
# KeyError: 'data'

# %%
df
# Out:
#                                                         datatable  \
# columns         [{'name': 'ticker', 'type': 'String'}, {'name'...
# data            [[A, 1999-11-18, 45.5, 50.0, 40.0, 44.0, 44739...
# next_cursor_id                                                NaN
#
#                                         meta
# columns                                  NaN
# data                                     NaN
# next_cursor_id  djFfMTAwMDFfMTUxNDYwNTc3NA==
